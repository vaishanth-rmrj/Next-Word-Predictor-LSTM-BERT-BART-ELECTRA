# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Mounting G-Drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# change to working directory
# !cd /content/drive/MyDrive/self_projects/next_word_predictor

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 39.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 62.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### LSTM model

# %%
# laoding model and tokenizer
lstm_model = load_model('lstm_model.h5')
lstm_tokenizer = pickle.load(open('lstm_tokenizer.pkl', 'rb'))

# %%
from utils.predict import lstm_next_word_pred

# %%
text1 = "Hey there! Good to know that you are doing"
next_word = lstm_next_word_pred(lstm_model, lstm_tokenizer, text1)

print("Sentence: ", text1)
print("Next word:", next_word)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Sentence:  Hey there! Good to know that you are doing
# Next word: [['nothing', 0.08465517], ['your', 0.088759966], ['so', 0.12043622], ['anything', 0.14124103]]

# %% [markdown]
# ### BERT Model

# %%
from transformers import BertTokenizer, BertForMaskedLM

bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertForMaskedLM.from_pretrained('bert-base-uncased').eval()
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from utils.predict import bert_next_word_pred

# %%
text1 = "Hey there! Good to know that you are doing <mask>"
next_words = bert_next_word_pred(bert_model, bert_tokenizer, text1, 4)

print("Sentence: ", text1)
print("Next word:", next_words)
# Out:
# Sentence:  Hey there! Good to know that you are doing <mask>
# Next word: well
# great
# okay
# good

# %% [markdown]
# ### BART model

# %%
from transformers import BartTokenizer, BartForConditionalGeneration
bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')
bart_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large').eval()

# %%
from utils.predict import bart_next_word_pred

# %%
text1 = "Hey there! Good to know that you are doing <mask>"
next_words = bart_next_word_pred(bart_model, bart_tokenizer, text1, 4)

print("Sentence: ", text1)
print("Next word:", next_words)
# Out:
# Sentence:  Hey there! Good to know that you are doing <mask>
# Next word: well
# so
# okay
# ok

# %% [markdown]
# ### Electra Model

# %%
from transformers import ElectraTokenizer, ElectraForMaskedLM
electra_tokenizer = ElectraTokenizer.from_pretrained('google/electra-small-generator')
electra_model = ElectraForMaskedLM.from_pretrained('google/electra-small-generator').eval()
# Out:
# ...
# Some weights of ElectraForMaskedLM were not initialized from the model checkpoint at google/electra-small-generator and are newly initialized: ['electra.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from utils.predict import electra_next_word_pred

# %%
text1 = "Hey there! Good to know that you are doing <mask>"
next_words = electra_next_word_pred(electra_model, electra_tokenizer, text1, 4)

print("Sentence: ", text1)
print("Next word:", next_words)
# Out:
# Sentence:  Hey there! Good to know that you are doing <mask>
# Next word: it
# this
# well
# that
